# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv',encoding="ISO-8859-1")

# %%
data
# Out:
#          pnn          id                          date     query  \
# 0          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 5          0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 6          0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7          0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 8          0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
# 9          0  1467812416  Mon Apr 06 22:20:16 PDT 2009  NO_QUERY
# 10         0  1467812579  Mon Apr 06 22:20:17 PDT 2009  NO_QUERY
# 11         0  1467812723  Mon Apr 06 22:20:19 PDT 2009  NO_QUERY
# 12         0  1467812771  Mon Apr 06 22:20:19 PDT 2009  NO_QUERY
# ...

# %%
data.size
# Out:
# 6291450

# %%
data.head()
# Out:
#    pnn          id                          date     query     tweeter_id  \
# 0    0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1    0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2    0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3    0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4    0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                               tweets
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
print("Dataset size:", len(data))
# Out:
# Dataset size: 1048575

# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv('cleaned_tweets.csv',encoding="ISO-8859-1")
# shuffling the dataset
data = data.sample(frac=1)

# %%
data.head()
# Out:
#         Unnamed: 0  pnn          id                          date     query  \
# 611168      719754    0  2260690723  Sat Jun 20 19:37:23 PDT 2009  NO_QUERY
# 327104      133432    0  1836000434  Mon May 18 07:10:40 PDT 2009  NO_QUERY
# 981054      243527    0  1981563881  Sun May 31 09:25:09 PDT 2009  NO_QUERY
# 819314       22836    0  1557579414  Sun Apr 19 04:57:00 PDT 2009  NO_QUERY
# 118143      667239    0  2245547242  Fri Jun 19 16:17:20 PDT 2009  NO_QUERY
#
#             tweeter_id                                             tweets
# 611168         Atefeh_  damn also favorite flavor trying make eat ice ...
# 327104             qtr      damn believe prison break found end miss show
# 981054      laurencruz      feeling little sick ohhellnoooo hope migraine
# 819314         alanakf                    disappointed damn getting hopes
# 118143  ninjalordkyros               cant think one doesnt google answers

# %%
data.tail()
# Out:
#          Unnamed: 0  pnn          id                          date     query  \
# 1028791      635925    0  2233770409  Thu Jun 18 21:52:23 PDT 2009  NO_QUERY
# 206338        20499    0  1557083612  Sun Apr 19 01:55:29 PDT 2009  NO_QUERY
# 552589       647307    0  2236729560  Fri Jun 19 04:24:19 PDT 2009  NO_QUERY
# 568864       770040    0  2301855208  Tue Jun 23 16:00:15 PDT 2009  NO_QUERY
# 598163       300958    0  1998474008  Mon Jun 01 18:36:30 PDT 2009  NO_QUERY
#
#              tweeter_id                                             tweets
# 1028791       amandarie    vodka always trick finishing last mike lemonade
# 206338           Leti_B                   omg wow great night time go home
# 552589   chaddoesdesign                              sorry hear teeter bro
# 568864           beet09  note designer developers try work weather 2 ma...
# 598163      adrianainks                            none buddies wanna talk

# %%
data
# Out:
#          Unnamed: 0  pnn          id                          date     query  \
# 611168       719754    0  2260690723  Sat Jun 20 19:37:23 PDT 2009  NO_QUERY
# 327104       133432    0  1836000434  Mon May 18 07:10:40 PDT 2009  NO_QUERY
# 981054       243527    0  1981563881  Sun May 31 09:25:09 PDT 2009  NO_QUERY
# 819314        22836    0  1557579414  Sun Apr 19 04:57:00 PDT 2009  NO_QUERY
# 118143       667239    0  2245547242  Fri Jun 19 16:17:20 PDT 2009  NO_QUERY
# 1005703      467146    0  2175715435  Mon Jun 15 01:47:06 PDT 2009  NO_QUERY
# 756169       686193    0  2250972431  Sat Jun 20 02:02:21 PDT 2009  NO_QUERY
# 675566       459402    0  2072165754  Sun Jun 07 20:31:02 PDT 2009  NO_QUERY
# 723496       834691    1  1558024081  Sun Apr 19 06:59:15 PDT 2009  NO_QUERY
# 701936       761565    0  2297326373  Tue Jun 23 10:18:14 PDT 2009  NO_QUERY
# 956137       647507    0  2236780701  Fri Jun 19 04:31:14 PDT 2009  NO_QUERY
# ...

# %%
data.size
# Out:
# 7340025

# %%
data['pnn'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['id'].unique()
# Out:
# array([2260690723, 1836000434, 1981563881, ..., 2236729560, 2301855208,
#        1998474008], dtype=int64)

# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data['tweeter_id'].unique()
# Out:
# array(['Atefeh_', 'qtr', 'laurencruz', ..., 'LeahLupu', 'chaddoesdesign',
#        'adrianainks'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer

# %%
# nltk.download('stopwords')

# %%
#stemmer: All words to root word 
stop_words = stopwords.words("english")
stemmer = SnowballStemmer("english")

# %%
import re
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"
# rough = '@#$prerana is the https://www.google.com great23'
# re.sub(TEXT_CLEANING_RE,' ',rough)

# %%
# ## stemming
# print(stemmer.stem('loved'))
# print(stemmer.stem('love'))

# %%
def preprocess(text, stem=False):
    # Remove link,user and special characters
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = []
    for token in text.split():
        if token not in stop_words:
            if stem:
                tokens.append(stemmer.stem(token))
            else:
                tokens.append(token)
    return " ".join(tokens)

# %%
# we apply preprocess function for cleaning the text data to every
# row of the text
# data['tweets'] = data['tweets'].apply(lambda x : preprocess(x))

# %%
#data.to_csv('cleaned_tweets')

# %%
# %matplotlib inline
data['pnn'].value_counts().plot(kind= 'bar')

# %%
df1=data[data["pnn"]==0]

# %%
df1
# Out:
#          Unnamed: 0  pnn          id                          date     query  \
# 611168       719754    0  2260690723  Sat Jun 20 19:37:23 PDT 2009  NO_QUERY
# 327104       133432    0  1836000434  Mon May 18 07:10:40 PDT 2009  NO_QUERY
# 981054       243527    0  1981563881  Sun May 31 09:25:09 PDT 2009  NO_QUERY
# 819314        22836    0  1557579414  Sun Apr 19 04:57:00 PDT 2009  NO_QUERY
# 118143       667239    0  2245547242  Fri Jun 19 16:17:20 PDT 2009  NO_QUERY
# 1005703      467146    0  2175715435  Mon Jun 15 01:47:06 PDT 2009  NO_QUERY
# 756169       686193    0  2250972431  Sat Jun 20 02:02:21 PDT 2009  NO_QUERY
# 675566       459402    0  2072165754  Sun Jun 07 20:31:02 PDT 2009  NO_QUERY
# 701936       761565    0  2297326373  Tue Jun 23 10:18:14 PDT 2009  NO_QUERY
# 956137       647507    0  2236780701  Fri Jun 19 04:31:14 PDT 2009  NO_QUERY
# 366552       554191    0  2203797025  Wed Jun 17 00:33:26 PDT 2009  NO_QUERY
# ...

# %%
df2=data[data["pnn"]==1]

# %%
df2
# Out:
#          Unnamed: 0  pnn          id                          date     query  \
# 723496       834691    1  1558024081  Sun Apr 19 06:59:15 PDT 2009  NO_QUERY
# 505035       937170    1  1793162246  Thu May 14 01:36:54 PDT 2009  NO_QUERY
# 840411       847935    1  1564691430  Mon Apr 20 04:34:15 PDT 2009  NO_QUERY
# 865922       915579    1  1753136686  Sun May 10 00:16:45 PDT 2009  NO_QUERY
# 52496        938449    1  1793459036  Thu May 14 02:46:33 PDT 2009  NO_QUERY
# 561376      1018010    1  1881946153  Fri May 22 05:54:55 PDT 2009  NO_QUERY
# 319765       914642    1  1752919341  Sat May 09 23:26:51 PDT 2009  NO_QUERY
# 332024       898243    1  1693558664  Sun May 03 22:57:04 PDT 2009  NO_QUERY
# 562526       968125    1  1827837401  Sun May 17 11:33:02 PDT 2009  NO_QUERY
# 270876       982566    1  1834213067  Mon May 18 02:03:52 PDT 2009  NO_QUERY
# 390425       947483    1  1823084004  Sat May 16 21:04:37 PDT 2009  NO_QUERY
# ...

# %%
data['tweets'].unique()
# Out:
# array(['damn also favorite flavor trying make eat ice cream approve',
#        'damn believe prison break found end miss show',
#        'feeling little sick ohhellnoooo hope migraine', ...,
#        'sorry hear teeter bro',
#        'note designer developers try work weather 2 major mistakes yesterday bk 2 sqr 1',
#        'none buddies wanna talk'], dtype=object)

# %%
data.shape
# Out:
# (1048575, 7)

# %%
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import itertools
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import re
import numpy as np
import os
from collections import Counter
import itertools

# %%
pnn_cnt = Counter(data.pnn)

plt.figure(figsize=(16,8))
plt.bar(pnn_cnt.keys(), pnn_cnt.values())
plt.title("Dataset labels distribuition")
# Out:
# Text(0.5,1,'Dataset labels distribuition')

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# train_pos = train[ data['pnn'] == 0]
# train_pos = train_pos['text']
# train_neg = train[ train['sentiment'] == 'Negative']
# train_neg = train_neg['text']
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=stop_words,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
#astype:type changing

# %%
data['tweets'] = data['tweets'].astype('str')

# %%
# negative workcloud
wordcloud_draw(data[data['pnn'] == 0]['tweets'])

# %%
# positive wordcloud
wordcloud_draw(data[data['pnn'] == 1]['tweets'] )

# %%
#Overall frequency of data
wordlist = nltk.FreqDist(" ".join(data['tweets']).split() )

# %%
wordcloud_draw(wordlist)

# %% [markdown]
# ### DATA CLASSIFIER PART

# %%
# Gaussian Naive Bayes
from sklearn import datasets
from sklearn import metrics
# fit a Naive Bayes model to the data
from sklearn.feature_selection import SelectKBest, chi2
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
import multiprocessing as ml

# %%
splitter = int(len(data) * .8)

# %%
splitter
# Out:
# 838860

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (1048575, 7)

# %%
#Vectorizer: changes text to number. 
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_df= 0.95,min_df= 0.001,
            tokenizer= lambda x: x.split(" "),decode_error='ignore',
            sublinear_tf= True )

# %%
vectorMatrixClean = vectorizer.fit_transform(data['tweets'])
vectorMatrixTrainClean = vectorMatrixClean[0:splitter]
vectorMatrixTestClean = vectorMatrixClean[splitter:]

# %%
vectorMatrixClean.shape
# Out:
# (1048575, 1046)

# %%
# data['pnn']=data['pnn'].astype(int,inplace = True)

# %%
data['pnn'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# def decoder(x):
#     if x == 4:
#         return 1
#     elif x == 0  : return 0

# %%
# data['pnn'] = data['pnn'].apply(lambda x : decoder(x))

# %%
labeldataset = data['pnn']
labelTrain = labeldataset[0:splitter]
labelTest = labeldataset[splitter:]

# %%
vectorMatrixTrainClean.shape
# Out:
# (838860, 1046)

# %%
def giveMetrics(nameCLF,trainedclf,trainData,trainLabel,testData,testLabel):
    trainScore = trainedclf.score(trainData,trainLabel)
    testScore = trainedclf.score(testData,testLabel)
    print('{} has following attributes : '.format(nameCLF))
    print('The training Accuracy of {} model is : {} '.format(nameCLF,trainScore))
    print('The testing Accuracy of {} model is : {} '.format(nameCLF,testScore))
    return trainScore,testScore

# %%
# naieve BAyes
clfMB = MultinomialNB(alpha=0.01)
clfMB.fit(vectorMatrixTrainClean,labelTrain)

giveMetrics('Multinomial Naive Bayes',clfMB,vectorMatrixTrainClean,labelTrain,vectorMatrixTestClean,labelTest)
#metrics.confusion_matrix(labelTest,clf1.predict(vectorMatrixTestClean))
# Out:
# Multinomial Naive Bayes has following attributes :
# The training Accuracy of Multinomial Naive Bayes model is : 0.7969994993205064
# The testing Accuracy of Multinomial Naive Bayes model is : 0.7966859785899911
# (0.7969994993205064, 0.7966859785899911)

# %%
clfBer = BernoulliNB().fit(vectorMatrixTrainClean,labelTrain)
giveMetrics('Bernoulli CLassifier',clfBer,vectorMatrixTrainClean,labelTrain,vectorMatrixTestClean,labelTest)
# Out:
# Bernoulli CLassifier has following attributes :
# The training Accuracy of Bernoulli CLassifier model is : 0.8096178146532198
# The testing Accuracy of Bernoulli CLassifier model is : 0.8085401616479508
# (0.8096178146532198, 0.8085401616479508)

# %%
clf_names = ['Multinomial-NB',' Bernoulli NB']
classifiers = [clfMB,clfBer]
overallScores = []
for clf_names,classifiers in zip(clf_names,classifiers):
    overallScores.append(giveMetrics(clf_names,classifiers,vectorMatrixTrainClean,labelTrain,vectorMatrixTestClean,labelTest))
# Out:
# Multinomial-NB has following attributes :
# The training Accuracy of Multinomial-NB model is : 0.7969994993205064
# The testing Accuracy of Multinomial-NB model is : 0.7966859785899911
#  Bernoulli NB has following attributes :
# The training Accuracy of  Bernoulli NB model is : 0.8096178146532198
# The testing Accuracy of  Bernoulli NB model is : 0.8085401616479508

# %%
overallScores
# Out:
# [(0.7969994993205064, 0.7966859785899911),
#  (0.8096178146532198, 0.8085401616479508)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
indices = np.arange(2)
test_score = np.array([i[1] for i in overallScores]) *100
train_score = np.array([i[0] for i in overallScores])*100

plt.figure(figsize=(12, 8))
plt.title("Score")
#plt.yscale('linear')

plt.barh(indices, test_score , .2, label="testing-score", color='darkorange')
plt.barh(indices + 0.2 , train_score , .2, label="training score",color='c')
#plt.barh(indices + .6, test_time, .2, label="test time", color='darkorange')
plt.yticks(())
plt.legend(loc='best')
plt.subplots_adjust(left=.25)
plt.subplots_adjust(top=.95)
plt.subplots_adjust(bottom=.05)
names = ['Multinomial-NB',' Bernoulli NB']
for i, c in zip(indices, names):
    plt.text(-25,i+0.05,c,fontsize = 13)
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
import itertools
cnf_matrix = confusion_matrix( labelTest , clfBer.predict(vectorMatrixTestClean)) 
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Negative','Positive'],normalize=True,
                      title='Confusion matrix, without normalization')
# Out:
# Normalized confusion matrix
# [[0.94 0.06]
#  [0.6  0.4 ]]

# %%
def predict(text,clf,vectorizer,preprocess):
    test_text = preprocess(text)
    vect_text = vectorizer.transform([test_text])
    out = clf.predict(vect_text)
    if out[0] == 0 :
        return 'The sentiment is Negative'
    else :
        return 'The sentiment is Positive'
# predict 
test_text = "you are bad good person"
predict(test_text,clfMB,vectorizer,preprocess)
# Out:
# 'The sentiment is Negative'

# %%
# predict 
test_text = "martin447,ahh thursday friday time fallout3"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Negative'

# %%
# predict 
test_text = "happy mothers day mom wish miss beyond words love mom x x x x"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Positive'

# %%
# predict 
test_text = "I failed exam"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Negative'

# %%
# predict 
test_text = "my mother cares for me"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Positive'

# %%
# predict 
test_text = "He scolded me"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Negative'

# %%
# predict 
test_text = "I love basketball"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Positive'

# %%
# predict 
test_text = "I hate bananas"
predict(test_text,clfBer,vectorizer,preprocess)
# Out:
# 'The sentiment is Negative'
